# %% [markdown]
# ## 분석데이터 csv 파일로 저장

# %%
import pandas as pd

# %%
# train_subway21 , train_subway22, train_subway23 동일 진행 

FILE_NAME = './dataset_file/train_subway23'

train_subway23_df = pd.read_csv(FILE_NAME)
train_subway23_df.shape
# Out:
# (5520981, 16)

# %%
train_subway23_df.columns
# Out:
# Index(['Unnamed: 0', 'train_subway23.tm', 'train_subway23.line',
#        'train_subway23.station_number', 'train_subway23.station_name',
#        'train_subway23.direction', 'train_subway23.stn', 'train_subway23.ta',
#        'train_subway23.wd', 'train_subway23.ws', 'train_subway23.rn_day',
#        'train_subway23.rn_hr1', 'train_subway23.hm', 'train_subway23.si',
#        'train_subway23.ta_chi', 'train_subway23.congestion'],
#       dtype='object')

# %%
train_subway23_df.drop(columns=['Unnamed: 0'], inplace = True)

# %%
train_subway23_df.columns
# Out:
# Index(['train_subway23.tm', 'train_subway23.line',
#        'train_subway23.station_number', 'train_subway23.station_name',
#        'train_subway23.direction', 'train_subway23.stn', 'train_subway23.ta',
#        'train_subway23.wd', 'train_subway23.ws', 'train_subway23.rn_day',
#        'train_subway23.rn_hr1', 'train_subway23.hm', 'train_subway23.si',
#        'train_subway23.ta_chi', 'train_subway23.congestion'],
#       dtype='object')

# %%
train_subway23_df
# Out:
#          train_subway23.tm  train_subway23.line  \
# 0               2023010100                    1
# 1               2023010101                    1
# 2               2023010105                    1
# 3               2023010106                    1
# 4               2023010107                    1
# ...                    ...                  ...
# 5520976         2023123119                    8
# 5520977         2023123120                    8
# 5520978         2023123121                    8
# 5520979         2023123122                    8
# 5520980         2023123123                    8
#
#          train_subway23.station_number train_subway23.station_name  \
# 0                                  150                         서울역
# 1                                  150                         서울역
# 2                                  150                         서울역
# 3                                  150                         서울역
# ...

# %%
train_subway23_df.to_csv('train_subway23.csv', index=False)

# %% [markdown]
# 데이터 확인

# %%
train_subway21_df
# Out:
#          train_subway21.tm  train_subway21.line  \
# 0               2021010100                    1
# 1               2021010101                    1
# 2               2021010105                    1
# 3               2021010106                    1
# 4               2021010107                    1
# ...                    ...                  ...
# 5452138         2021123119                    8
# 5452139         2021123120                    8
# 5452140         2021123121                    8
# 5452141         2021123122                    8
# 5452142         2021123123                    8
#
#          train_subway21.station_number train_subway21.station_name  \
# 0                                  150                         서울역
# 1                                  150                         서울역
# 2                                  150                         서울역
# 3                                  150                         서울역
# ...

# %%
train_subway22_df
# Out:
#          train_subway22.tm  train_subway22.line  \
# 0               2022010100                    1
# 1               2022010101                    1
# 2               2022010105                    1
# 3               2022010106                    1
# 4               2022010107                    1
# ...                    ...                  ...
# 5396195         2022123119                    8
# 5396196         2022123120                    8
# 5396197         2022123121                    8
# 5396198         2022123122                    8
# 5396199         2022123123                    8
#
#          train_subway22.station_number train_subway22.station_name  \
# 0                                  150                         서울역
# 1                                  150                         서울역
# 2                                  150                         서울역
# 3                                  150                         서울역
# ...

# %%
train_subway23_df
# Out:
#          train_subway23.tm  train_subway23.line  \
# 0               2023010100                    1
# 1               2023010101                    1
# 2               2023010105                    1
# 3               2023010106                    1
# 4               2023010107                    1
# ...                    ...                  ...
# 5520976         2023123119                    8
# 5520977         2023123120                    8
# 5520978         2023123121                    8
# 5520979         2023123122                    8
# 5520980         2023123123                    8
#
#          train_subway23.station_number train_subway23.station_name  \
# 0                                  150                         서울역
# 1                                  150                         서울역
# 2                                  150                         서울역
# 3                                  150                         서울역
# ...
