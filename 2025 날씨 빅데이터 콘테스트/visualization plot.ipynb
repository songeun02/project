# %% [markdown]
# ## 상관계수 비교 시각화

# %%
pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 44.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# 연도별 상관계수 시각화

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
variable = ['STN','TA','WD','WS','RN_DAY','RN_HR1','HM','SI','ta_chi']
corr_2021 = [0.131905,	0.008428,	0.00027,	-0.01202,	-0.030702,	-0.013793,	-0.052405,	-0.070407,	0.002511]
corr_2022 = [0.114425,	0.001727,	0.004210,	-0.018370,	-0.015976,	-0.005806,	-0.038503,	-0.082180,	-0.004588]
corr_2023 = [0.119858	,-0.001193, 0.014057,	0.005060,	-0.018994,	-0.022146,	-0.056194,	-0.077465,	-0.006787]
corr_total = [0.119785,	0.002309,	0.012541,	-0.010877,	-0.012507,	-0.010213	,-0.048824,	-0.073103,	-0.003021]

# %%
plt.plot(variable, corr_2021,'s--', label='2021년')
plt.plot(variable, corr_2022,'s--', label='2022년')
plt.plot(variable, corr_2023,'s--', label='2023년')
plt.plot(variable, corr_total,'s--', label='전체')
plt.title('연도별 기상과 지하철 혼잡도 상관계수 선그래프')
plt.legend()
plt.show()

# %% [markdown]
# pearson 상관분석 - 월별 상관계수 시각화

# %%
variable = ['STN','TA','WD','WS','RN_DAY','RN_HR1','HM','SI','ta_chi']

month_1 = [0.122419,	0.044312,	0.006382,	-0.024921,	0.05168,	0.044059,	0.029947,	-0.176609,	0.044145]
month_2 = [0.123065,	0.014887,	-0.011101,	-0.052765,	-0.032132,	-0.005993,	-0.023788,	-0.137255,	0.024775]
month_3 = [0.122786,	0.081284,	-0.000427,	-0.050891,	-0.12658,	-0.085814,	-0.140888,	-0.086051,	0.090205]
month_4 = [0.121387,	0.031086,	-0.002549,	-0.008684,	0.01069, -0.017571,	-0.021703,	-0.076364,	0.033351]
month_5 = [0.116835,	0.138448,	-0.001693,	0.003423,	-0.070194,	-0.060592,	-0.130711,	0.013722,	0.109924]
month_6 = [0.118287,	0.068871,	0.026049,	0.000763, 0.002921,	-0.010716,	-0.049843,	-0.011633,	0.054798]
month_7 = [0.121324,	0.012508,	0.023077,	0.007339,	0.038346,	0.007713,	-0.005513,	-0.050405,	0.005867]
month_8 = [0.119902,	0.045357,	0.01472,	0.02055,	0.015909,	0.013293,	-0.045272,	-0.025386,	0.032443]
month_9 = [0.11754,	0.026057,	0.007243,	0.001727,	-0.02869,	-0.008889,	-0.019954,	-0.094136,	0.016407]
month_10 = [0.12455,	-0.035741,	0.0197,	-0.041389,	-0.061585,	-0.013853,	-0.063439,	-0.093672,	-0.036059]
month_11 = [0.123714,	-0.025176,	0.034857,	-0.010659,	-0.013883,	-0.005826,	-0.00699,	-0.200069,	-0.025795]
month_12 = [0.112656,	0.017929,	0.008844,	0.000067,	0.040634,	0.020287,	0.019457,	-0.175721,	0.01687]

# %%
plt.plot(variable, month_1,'s--', label='1월')
plt.plot(variable, month_2,'s--', label='2월')
plt.plot(variable, month_3,'s--', label='3월')
plt.plot(variable, month_4,'s--', label='4월')
plt.plot(variable, month_5,'s--', label='5월')
plt.plot(variable, month_6,'s--', label='6월')
plt.plot(variable, month_7,'s--', label='7월')
plt.plot(variable, month_8,'s--', label='8월')
plt.plot(variable, month_9,'s--', label='9월')
plt.plot(variable, month_10,'s--', label='10월')
plt.plot(variable, month_11,'s--', label='11월')
plt.plot(variable, month_12,'s--', label='12월')
plt.title('월별 기상과 지하철 혼잡도 상관계수 선그래프')
plt.legend(loc='upper right', bbox_to_anchor=(1.32, 1))
plt.show()

# %% [markdown]
# pearson 상관분석 - 계절별 상관계수 시각화

# %%
variable = ['STN','TA','WD','WS','RN_DAY','RN_HR1','HM','SI','ta_chi']

spring = [0.120055,	0.06462,	-0.001711,	-0.015652,	-0.059671,	-0.052486,	-0.095754,	-0.043043,	0.054788]
summer = [0.120111,	0.018302,	0.023836,	0.011441,	0.016605,	0.002544,	-0.042658	,-0.024815	,0.000315]
fall = [0.121399,	-0.065124,	0.03437,	-0.015113,	-0.035262,	-0.012828,	-0.043109,	-0.128664,	-0.069266]
winter = [0.118699,	0.028729,	0.000951,	-0.026161,	0.040446,	0.029782,	0.021899	,-0.166888,	0.031467]

# %%
plt.plot(variable, spring,'s--', label='봄')
plt.plot(variable, summer,'s--', label='여름')
plt.plot(variable, fall,'s--', label='가을')
plt.plot(variable, winter,'s--', label='겨울')
plt.title('계절별 기상과 지하철 혼잡도 상관계수 선그래프')
plt.legend()
plt.show()

# %% [markdown]
# Pearson, Spearman 비교

# %%
variable = ['STN','TA','WD','WS','RN_DAY','RN_HR1','HM','SI','ta_chi']

sp = [0.067947,	0.016520,	0.019014,	0.039338,	-0.027083,	-0.026753,	-0.098509,	0.023843,	0.004669]
pe = [0.119785,	0.002309,	0.012541,	-0.010877,	-0.012507,	-0.010213,	-0.048824,	-0.073103,	-0.003021]

plt.plot(variable, sp,'s--', label='Spearman')
plt.plot(variable, pe,'s--', label='Pearson')
plt.title('Spearman 상관계수와 Pearson 상관계수 비교')
plt.legend()
plt.show()

# %% [markdown]
# 정규변환 전 후 상관계수 비교

# %%
variable = ['STN','TA','WD','WS','RN_DAY','RN_HR1','HM','SI','ta_chi']

before= [0.119785,	0.002309,	0.012541,	-0.010877,	-0.012507,	-0.010213,	-0.048824,	-0.073103,	-0.003021]
after = [0.117163,	0.027786,	0.011506,	0.027526,	-0.011087,	-0.007947,	-0.090970	,0.028637,	0.019922]


plt.plot(variable, before,'s--', label='변환 전')
plt.plot(variable, after,'s--', label='변환 후')
plt.title('정규 변환 전 후 비교')
plt.legend()
plt.show()
